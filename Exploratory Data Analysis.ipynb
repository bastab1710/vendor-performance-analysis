# %%
import pandas as pd
import sqlite3

# %%
# creating database connection
conn = sqlite3.connect('inventory.db')

# %%
#checking tables present in the database
tables = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table'",conn)
tables
# Out:
#               name
# 0   vendor_invoice
# 1  begin_inventory
# 2    end_inventory
# 3        purchases
# 4  purchase_prices
# 5            sales

# %%
for table in tables['name']:
    print('-'*50, f'{table}','-'*50)
    print('count of records:', pd.read_sql(f"select count(*) as count from {table}", conn)['count'].values[0])
    display(pd.read_sql(f"select * from {table} limit 100", conn))
# Out:
# -------------------------------------------------- vendor_invoice --------------------------------------------------
# count of records: 100
#     VendorNumber              VendorName InvoiceDate PONumber      PODate  \
# 0           1001        Nestle Suppliers  2025-03-05   PO1001  2025-03-01
# 1           1001        Nestle Suppliers  2025-06-19   PO1002  2025-06-15
# 2           1002  Haldirams Distributors  2025-05-04   PO1003  2025-04-30
# 3           1001        Nestle Suppliers  2025-04-04   PO1004  2025-03-30
# 4           1003       Britannia Vendors  2025-03-25   PO1005  2025-03-20
# ..           ...                     ...         ...      ...         ...
# 95          1003       Britannia Vendors  2025-05-26   PO1096  2025-05-22
# 96          1002  Haldirams Distributors  2025-03-30   PO1097  2025-03-26
# 97          1004          Amul Wholesale  2025-01-17   PO1098  2025-01-13
# 98          1002  Haldirams Distributors  2025-01-15   PO1099  2025-01-11
# ...

# %%
purchases =pd.read_sql_query("select * from purchases where VendorNumber = 1002", conn)
purchases
# Out:
#     InventoryId        Store      Brand    Description   Size  VendorNumber  \
# 0             3    SuperMart  Haldirams    Noodles 1kg    1kg          1002
# 1             6    GrociKart  Haldirams    Butter 100g   100g          1002
# 2            20  FreshBazaar  Haldirams  Biscuits 500g   500g          1002
# 3            30    GrociKart  Haldirams  Biscuits 100g   100g          1002
# 4            31  FreshBazaar  Haldirams         Tea 1L     1L          1002
# 5            33    GrociKart  Haldirams     Chips 100g   100g          1002
# 6            34    GrociKart  Haldirams       Tea 500g   500g          1002
# 7            35   DailyNeeds  Haldirams    Coffee 200g   200g          1002
# 8            37  FreshBazaar  Haldirams    Butter 500g   500g          1002
# 9            41    GrociKart  Haldirams     Butter 1kg    1kg          1002
# 10           43  FreshBazaar  Haldirams     Milk 250ml  250ml          1002
# ...

# %%
purchase_prices = pd.read_sql_query("""select * from purchases where VendorNumber = 1002""", conn)
purchase_prices
# Out:
#     InventoryId        Store      Brand    Description   Size  VendorNumber  \
# 0             3    SuperMart  Haldirams    Noodles 1kg    1kg          1002
# 1             6    GrociKart  Haldirams    Butter 100g   100g          1002
# 2            20  FreshBazaar  Haldirams  Biscuits 500g   500g          1002
# 3            30    GrociKart  Haldirams  Biscuits 100g   100g          1002
# 4            31  FreshBazaar  Haldirams         Tea 1L     1L          1002
# 5            33    GrociKart  Haldirams     Chips 100g   100g          1002
# 6            34    GrociKart  Haldirams       Tea 500g   500g          1002
# 7            35   DailyNeeds  Haldirams    Coffee 200g   200g          1002
# 8            37  FreshBazaar  Haldirams    Butter 500g   500g          1002
# 9            41    GrociKart  Haldirams     Butter 1kg    1kg          1002
# 10           43  FreshBazaar  Haldirams     Milk 250ml  250ml          1002
# ...

# %%
vendor_invoice = pd.read_sql_query("""select * from purchases where VendorNumber = 1002""", conn)
vendor_invoice
# Out:
#     InventoryId        Store      Brand    Description   Size  VendorNumber  \
# 0             3    SuperMart  Haldirams    Noodles 1kg    1kg          1002
# 1             6    GrociKart  Haldirams    Butter 100g   100g          1002
# 2            20  FreshBazaar  Haldirams  Biscuits 500g   500g          1002
# 3            30    GrociKart  Haldirams  Biscuits 100g   100g          1002
# 4            31  FreshBazaar  Haldirams         Tea 1L     1L          1002
# 5            33    GrociKart  Haldirams     Chips 100g   100g          1002
# 6            34    GrociKart  Haldirams       Tea 500g   500g          1002
# 7            35   DailyNeeds  Haldirams    Coffee 200g   200g          1002
# 8            37  FreshBazaar  Haldirams    Butter 500g   500g          1002
# 9            41    GrociKart  Haldirams     Butter 1kg    1kg          1002
# 10           43  FreshBazaar  Haldirams     Milk 250ml  250ml          1002
# ...

# %%
sales = pd.read_sql_query("""select * from purchases where VendorNumber = 1002""", conn)
sales
# Out:
#     InventoryId        Store      Brand    Description   Size  VendorNumber  \
# 0             3    SuperMart  Haldirams    Noodles 1kg    1kg          1002
# 1             6    GrociKart  Haldirams    Butter 100g   100g          1002
# 2            20  FreshBazaar  Haldirams  Biscuits 500g   500g          1002
# 3            30    GrociKart  Haldirams  Biscuits 100g   100g          1002
# 4            31  FreshBazaar  Haldirams         Tea 1L     1L          1002
# 5            33    GrociKart  Haldirams     Chips 100g   100g          1002
# 6            34    GrociKart  Haldirams       Tea 500g   500g          1002
# 7            35   DailyNeeds  Haldirams    Coffee 200g   200g          1002
# 8            37  FreshBazaar  Haldirams    Butter 500g   500g          1002
# 9            41    GrociKart  Haldirams     Butter 1kg    1kg          1002
# 10           43  FreshBazaar  Haldirams     Milk 250ml  250ml          1002
# ...

# %%
purchases.groupby(['Brand' , 'PurchasePrice'])[['Quantity' , 'Rupees']].sum()
# Out:
#                      Quantity   Rupees
# Brand PurchasePrice
# Amul  28.88                20    577.6
#       47.01                60   2820.6
#       57.90                50   2895.0
#       69.15                10    691.5
#       103.13               10   1031.3
# ...                       ...      ...
# Tata  154.66               60   9279.6
#       168.44               80  13475.2
#       171.97               30   5159.1
#       205.46               90  18491.4
#       237.43               50  11871.5
#
# [100 rows x 2 columns]

# %%
purchase_prices
# Out:
#     InventoryId        Store      Brand   Description  Size  VendorNumber  \
# 0             1    SuperMart     Nestle   Butter 500g  500g          1001
# 1             2   DailyNeeds     Nestle  Noodles 100g  100g          1001
# 2             3    SuperMart  Haldirams   Noodles 1kg   1kg          1002
# 3             4    MegaStore     Nestle    Noodles 1L    1L          1001
# 4             5    SuperMart  Britannia     Salt 200g  200g          1003
# ..          ...          ...        ...           ...   ...           ...
# 95           96  FreshBazaar  Britannia  Biscuits 1kg   1kg          1003
# 96           97    SuperMart  Haldirams      Tea 100g  100g          1002
# 97           98    MegaStore       Amul   Coffee 100g  100g          1004
# 98           99  FreshBazaar  Haldirams    Chips 100g  100g          1002
# 99          100    GrociKart  Haldirams   Coffee 500g  500g          1002
#
#                 VendorName PONumber      PODate ReceivingDate InvoiceDate  \
# ...

# %%
vendor_invoice.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'VendorNumber',
#        'VendorName', 'PONumber', 'PODate', 'ReceivingDate', 'InvoiceDate',
#        'PayDate', 'PurchasePrice', 'Quantity', 'Rupees', 'Classification'],
#       dtype='object')

# %%
vendor_invoice.shape
# Out:
# (25, 16)

# %%
vendor_invoice.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'VendorNumber',
#        'VendorName', 'PONumber', 'PODate', 'ReceivingDate', 'InvoiceDate',
#        'PayDate', 'PurchasePrice', 'Quantity', 'Rupees', 'Classification'],
#       dtype='object')

# %%
sales.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'VendorNumber',
#        'VendorName', 'PONumber', 'PODate', 'ReceivingDate', 'InvoiceDate',
#        'PayDate', 'PurchasePrice', 'Quantity', 'Rupees', 'Classification'],
#       dtype='object')

# %%
begin_inventory.columns
# Out:
# Index(['InventoryId', 'Store', 'City', 'Brand', 'Description', 'Size',
#        'onHand', 'Price', 'Startdate'],
#       dtype='object')

# %%
purchase_prices.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'VendorNumber',
#        'VendorName', 'PONumber', 'PODate', 'ReceivingDate', 'InvoiceDate',
#        'PayDate', 'PurchasePrice', 'Quantity', 'Rupees', 'Classification'],
#       dtype='object')

# %% [raw]
# end_inventory.columns

# %%
end_inventory.columns
# Out:
# Index(['InventoryId', 'Store', 'City', 'Brand', 'Description', 'Size',
#        'onHand', 'Price', 'Enddate'],
#       dtype='object')

# %%
sales.groupby('Brand')[['SalesRupees','SalesPrice','SalesQuantity']].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 sales.groupby('Brand')[['SalesRupees','SalesPrice','SalesQuantity']].sum()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\base.py:239, in SelectionMixin.__getitem__(self, key)
#     237     if len(self.obj.columns.intersection(key)) != len(set(key)):
# ...

# %%
import pandas as pd
import sqlite3

# Connect to the database
conn = sqlite3.connect("inventory.db")

# Load the sales and end_inventory tables
sales = pd.read_sql_query("SELECT * FROM sales", conn)
end_inventory = pd.read_sql_query("SELECT * FROM end_inventory", conn)
vendor_invoice = pd.read_sql_query("SELECT * FROM vendor_invoice", conn)
begin_inventory = pd.read_sql_query("SELECT * FROM begin_inventory", conn)
purchases = pd.read_sql_query("SELECT * FROM purchases", conn)
purchase_prices = pd.read_sql_query("SELECT * FROM purchases", conn)

# %%
end_inventory.columns
# Out:
# Index(['InventoryId', 'Store', 'City', 'Brand', 'Description', 'Size',
#        'onHand', 'Price', 'Enddate'],
#       dtype='object')

# %%
#checking tables present in the database
tables = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table'",conn)
tables
# Out:
#               name
# 0   vendor_invoice
# 1  begin_inventory
# 2    end_inventory
# 3        purchases
# 4  purchase_prices
# 5            sales

# %%
vendor_invoice.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'InvoiceDate', 'PONumber', 'PODate',
#        'PayDate', 'Quantity', 'Rupees', 'Freight', 'Approval'],
#       dtype='object')

# %%
sales.groupby('Brand')[['SalesRupees','SalesPrice','SalesQuantity']].sum()
# Out:
#            SalesRupees  SalesPrice  SalesQuantity
# Brand
# Amul         154557.90     2298.46            840
# Britannia    171698.10     2866.48           1275
# Haldirams    212650.15     3667.67           1450
# Nestle       198505.30     3119.25           1285
# Tata         170022.70     2691.86           1200

# %%
purchases.groupby('Brand')[['PurchasePrice','Quantity','Rupees']].sum()
# Out:
#            PurchasePrice  Quantity     Rupees
# Brand
# Amul             1723.83       840  115917.20
# Britannia        2293.17      1275  137357.40
# Haldirams        2750.75      1450  159487.65
# Nestle           2495.40      1285  158804.00
# Tata             2153.49      1200  136018.50

# %% [markdown]
# ### Key Observations
#
#
# - The purchases table contains actual purchase data, including the date of purchase, products (brands) purchased by vendors, the amount paid (in rupees), and the quantity purchased.
# - The purchase_prices column is derived from the purchase_prices table, which provides product-wise actual and purchase prices. The combination of vendor and brand is unique in this table.
# - The vendor_invoice table aggregates data from the purchases table, summarizing quantity and rupees amounts, along with an additional column for freight. This table maintains uniqueness based on vendor and PO number.
# - The sales table captures actual sales transactions, detailing the brands purchased by vendors, the quantity sold, the selling price, and the revenue earned.
#
# ---
#
# ### As the data that we need for analysis is distributed in different tables, we need to create a summary table containing:
#
# - Purchase transactions made by vendors
# - Sales transaction data
# - Freight costs for each vendor
# - Actual product prices from vendors

# %%
vendor_invoice.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'InvoiceDate', 'PONumber', 'PODate',
#        'PayDate', 'Quantity', 'Rupees', 'Freight', 'Approval'],
#       dtype='object')

# %%
freight_summary = pd.read_sql_query("""select VendorNumber, SUM(Freight) as FreightCost
From vendor_invoice
Group BY VendorNumber""", conn)

# %%
freight_summary
# Out:
#    VendorNumber  FreightCost
# 0          1001     15880.40
# 1          1002     15948.77
# 2          1003     13735.74
# 3          1004     11591.72
# 4          1005     13601.85

# %%
freight_summary = pd.read_sql_query("""select VendorNumber, SUM(Freight) as FreightCost
From vendor_invoice
Group BY VendorNumber""", conn)

# %%
freight_summary
# Out:
#    VendorNumber  FreightCost
# 0          1001     15880.40
# 1          1002     15948.77
# 2          1003     13735.74
# 3          1004     11591.72
# 4          1005     13601.85

# %%
purchases.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'VendorNumber',
#        'VendorName', 'PONumber', 'PODate', 'ReceivingDate', 'InvoiceDate',
#        'PayDate', 'PurchasePrice', 'Quantity', 'Rupees', 'Classification'],
#       dtype='object')

# %%
purchase_prices.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'VendorNumber',
#        'VendorName', 'PONumber', 'PODate', 'ReceivingDate', 'InvoiceDate',
#        'PayDate', 'PurchasePrice', 'Quantity', 'Rupees', 'Classification'],
#       dtype='object')

# %%
import pandas as pd
import sqlite3

# Connect to the database
conn = sqlite3.connect("inventory.db")

# Load the sales and end_inventory tables
sales = pd.read_sql_query("SELECT * FROM sales", conn)
end_inventory = pd.read_sql_query("SELECT * FROM end_inventory", conn)
vendor_invoice = pd.read_sql_query("SELECT * FROM vendor_invoice", conn)
begin_inventory = pd.read_sql_query("SELECT * FROM begin_inventory", conn)
purchases = pd.read_sql_query("SELECT * FROM purchases", conn)
purchase_prices = pd.read_sql_query("SELECT * FROM purchase_prices", conn)

# %%
purchases.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'VendorNumber',
#        'VendorName', 'PONumber', 'PODate', 'ReceivingDate', 'InvoiceDate',
#        'PayDate', 'PurchasePrice', 'Quantity', 'Rupees', 'Classification'],
#       dtype='object')

# %%
purchase_prices.columns
# Out:
# Index(['Brand', 'Description', 'Price', 'Size', 'Volume', 'Classification',
#        'PurchasePrice', 'VendorNumber', 'VendorName'],
#       dtype='object')

# %%
pd.read_sql_query("""SELECT
p.VendorNumber,
p.VendorName,
p.Brand,
p.PurchasePrice,
pp.Volume,
pp.Price as ActualPrice,
SUM(p.Quantity) as TotalPurchaseQuantity,
SUM(p.Rupees) as TotalPurchaseRupees
FROM purchases p
JOIN purchase_prices pp
ON p.Brand = pp.Brand
GROUP BY p.VendorNumber, p.VendorName, p.Brand
ORDER BY TotalPurchaseRupees""",conn)
# Out:
#    VendorNumber              VendorName      Brand  PurchasePrice  Volume  \
# 0          1004          Amul Wholesale       Amul         132.08     100
# 1          1005              Tata Foods       Tata          65.19    1000
# 2          1003       Britannia Vendors  Britannia          95.05     500
# 3          1001        Nestle Suppliers     Nestle          24.85     100
# 4          1002  Haldirams Distributors  Haldirams         115.28    1000
#
#    ActualPrice  TotalPurchaseQuantity  TotalPurchaseRupees
# 0        38.51                  11760           1622840.80
# 1        28.62                  22800           2584351.50
# 2        53.78                  25500           2747148.00
# 3        30.20                  28270           3493688.00
# 4        16.66                  36250           3987191.25

# %%
sales.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'SalesQuantity',
#        'SalesRupees', 'SalesPrice', 'SalesDate', 'Volume', 'Classification',
#        'ExciseTax', 'VendorNumber', 'VendorName'],
#       dtype='object')

# %%
pd.read_sql_query("""SELECT
VendorNumber,
Brand,
SUM(SalesRupees) as TotalSalesRupees,
SUM(SalesPrice) as TotalSalesPrice,
SUM(SalesQuantity) as TotalSalesQuantity,
SUM(ExciseTax) as TotalExciseTax
FROM sales
GROUP BY VendorNumber, Brand
ORDER BY TotalSalesRupees""",conn)
# Out:
#    VendorNumber      Brand  TotalSalesRupees  TotalSalesPrice  \
# 0          1004       Amul         154557.90          2298.46
# 1          1005       Tata         170022.70          2691.86
# 2          1003  Britannia         171698.10          2866.48
# 3          1001     Nestle         198505.30          3119.25
# 4          1002  Haldirams         212650.15          3667.67
#
#    TotalSalesQuantity  TotalExciseTax
# 0                 840        15455.79
# 1                1200        17002.27
# 2                1275        17169.81
# 3                1285        19850.53
# 4                1450        21265.02

# %%
import pandas as pd
import sqlite3

# Connect to the database
conn = sqlite3.connect("inventory.db")

# Load the sales and end_inventory tables
sales = pd.read_sql_query("SELECT * FROM sales", conn)
end_inventory = pd.read_sql_query("SELECT * FROM end_inventory", conn)
vendor_invoice = pd.read_sql_query("SELECT * FROM vendor_invoice", conn)
begin_inventory = pd.read_sql_query("SELECT * FROM begin_inventory", conn)
purchases = pd.read_sql_query("SELECT * FROM purchases", conn)
purchase_prices = pd.read_sql_query("SELECT * FROM purchase_prices", conn)

# %%
import pandas as pd
import sqlite3

# Connect to the database
conn = sqlite3.connect("inventory.db")

# Load the sales and end_inventory tables
sales = pd.read_sql_query("SELECT * FROM sales", conn)
end_inventory = pd.read_sql_query("SELECT * FROM end_inventory", conn)
vendor_invoice = pd.read_sql_query("SELECT * FROM vendor_invoice", conn)
begin_inventory = pd.read_sql_query("SELECT * FROM begin_inventory", conn)
purchases = pd.read_sql_query("SELECT * FROM purchases", conn)
purchase_prices = pd.read_sql_query("SELECT * FROM purchase_prices", conn)

# %%
import pandas as pd
import sqlite3

# Connect to the database
conn = sqlite3.connect("inventory.db")

# Load the sales and end_inventory tables
sales = pd.read_sql_query("SELECT * FROM sales", conn)
end_inventory = pd.read_sql_query("SELECT * FROM end_inventory", conn)
vendor_invoice = pd.read_sql_query("SELECT * FROM vendor_invoice", conn)
begin_inventory = pd.read_sql_query("SELECT * FROM begin_inventory", conn)
purchases = pd.read_sql_query("SELECT * FROM purchases", conn)
purchase_prices = pd.read_sql_query("SELECT * FROM purchase_prices", conn)

# %%
import pandas as pd
import sqlite3

# Connect to the database
conn = sqlite3.connect("inventory.db")

# Load the sales and end_inventory tables
sales = pd.read_sql_query("SELECT * FROM sales", conn)
end_inventory = pd.read_sql_query("SELECT * FROM end_inventory", conn)
vendor_invoice = pd.read_sql_query("SELECT * FROM vendor_invoice", conn)
begin_inventory = pd.read_sql_query("SELECT * FROM begin_inventory", conn)
purchases = pd.read_sql_query("SELECT * FROM purchases", conn)
purchase_prices = pd.read_sql_query("SELECT * FROM purchase_prices", conn)

# %%
import time
start = time.time()
final_table = pd.read_sql_query("""SELECT
    pp.VendorNumber,
    pp.Brand,
    pp.Price as ActualPrice,
    pp.PurchasePrice,
    SUM(s.SalesQuantity) AS TotalSalesQuantity,
    SUM(s.SalesRupees) AS TotalSalesRupees,
    SUM(s.SalesPrice) AS TotalSalesPrice,
    SUM(s.ExciseTax) AS TotalExciseTax,
    SUM(vi.Quantity) AS TotalPurchaseQuantity,
    SUM(vi.Rupees) AS TotalPurchaseRupees,
    SUM(vi.Freight) AS TotalFreightCost
    FROM purchase_prices pp
JOIN sales s
    ON pp.VendorNumber = s.VendorNumber
    AND pp.Brand = s.Brand
JOIN vendor_invoice vi
    ON pp.VendorNumber = vi.VendorNumber
GROUP BY pp.VendorNumber, pp.Brand, pp.PurchasePrice
""",conn)
end = time.time()

# %%
final_table
# Out:
#     VendorNumber   Brand  ActualPrice  PurchasePrice  TotalSalesQuantity  \
# 0           1001  Nestle        30.20          24.16               28270
# 1           1001  Nestle        31.06          24.85               28270
# 2           1001  Nestle        40.29          32.23               28270
# 3           1001  Nestle        46.52          37.22               28270
# 4           1001  Nestle        56.25          45.00               28270
# ..           ...     ...          ...            ...                 ...
# 95          1005    Tata       193.32         154.66               22800
# 96          1005    Tata       210.55         168.44               22800
# 97          1005    Tata       214.96         171.97               22800
# 98          1005    Tata       256.82         205.46               22800
# 99          1005    Tata       296.79         237.43               22800
#
#     TotalSalesRupees  TotalSalesPrice  TotalExciseTax  TotalPurchaseQuantity  \
# ...

# %% [markdown]
# ### Optimized way of doing the above aggregated table, it is done when the amount of data in the dataset in too large

# %%
vendor_sales_summary = pd.read_sql_query("""WITH FreightSummary AS (
    SELECT
        VendorNumber,
        SUM(Freight) AS FreightCost
    FROM vendor_invoice
    GROUP BY VendorNumber
),

PurchaseSummary AS (
    SELECT
        p.VendorNumber,
        p.VendorName,
        p.Brand,
        p.Description,
        p.PurchasePrice,
        pp.Price AS ActualPrice,
        pp.Volume,
        SUM(p.Quantity) AS TotalPurchaseQuantity,
        SUM(p.Rupees) AS TotalPurchaseRupees
    FROM purchases p
    JOIN purchase_prices pp
        ON p.Brand = pp.Brand
    WHERE p.PurchasePrice > 0
    GROUP BY p.VendorNumber, p.VendorName, p.Brand, p.Description, p.PurchasePrice, pp.Price, pp.Volume
),

SalesSummary AS (
    SELECT
        VendorNumber,
        Brand,
        SUM(SalesQuantity) AS TotalSalesQuantity,
        SUM(SalesRupees) AS TotalSalesRupees,
        SUM(SalesPrice) AS TotalSalesPrice,
        SUM(ExciseTax) AS TotalExciseTax
    FROM sales
    GROUP BY VendorNumber, Brand
)

SELECT
    ps.VendorNumber,
    ps.VendorName,
    ps.Brand,
    ps.Description,
    ps.PurchasePrice,
    ps.ActualPrice,
    ps.Volume,
    ps.TotalPurchaseQuantity,
    ps.TotalPurchaseRupees,
    ss.TotalSalesQuantity,
    ss.TotalSalesRupees,
    ss.TotalSalesPrice,
    ss.TotalExciseTax,
    fs.FreightCost
FROM PurchaseSummary ps
LEFT JOIN SalesSummary ss
    ON ps.VendorNumber = ss.VendorNumber
    AND ps.Brand = ss.Brand
LEFT JOIN FreightSummary fs
    ON ps.VendorNumber = fs.VendorNumber
ORDER BY ps.TotalPurchaseRupees DESC""",conn)

# %%
vendor_sales_summary
# Out:
#       VendorNumber        VendorName   Brand   Description  PurchasePrice  \
# 0             1001  Nestle Suppliers  Nestle  Biscuits 1kg         219.74
# 1             1001  Nestle Suppliers  Nestle  Biscuits 1kg         219.74
# 2             1001  Nestle Suppliers  Nestle  Biscuits 1kg         219.74
# 3             1001  Nestle Suppliers  Nestle  Biscuits 1kg         219.74
# 4             1001  Nestle Suppliers  Nestle  Biscuits 1kg         219.74
# ...            ...               ...     ...           ...            ...
# 2061          1001  Nestle Suppliers  Nestle  Noodles 100g          24.16
# 2062          1001  Nestle Suppliers  Nestle  Noodles 100g          24.16
# 2063          1001  Nestle Suppliers  Nestle  Noodles 100g          24.16
# 2064          1001  Nestle Suppliers  Nestle  Noodles 100g          24.16
# 2065          1001  Nestle Suppliers  Nestle  Noodles 100g          24.16
#
#       ActualPrice  Volume  TotalPurchaseQuantity  TotalPurchaseRupees  \
# ...

# %% [markdown]
# This query generates a vendor-wise sales and purchase summary, which is valuable for:
#
# **Performance Optimization:**
#
# - The query involves heavy joins and aggregations on large datasets like sales and purchases.
# - Storing the pre-aggregated results avoids repeated expensive computations.
# - Helps in analyzing sales, purchases, and pricing for different vendors and brands.
# - Future Benefits of Storing this data for faster Dashboarding & Reporting.
# - Instead of running expensive queries each time, dashboards can fetch data quickly from `vendor_sales_summary`.

# %%
vendor_sales_summary.dtypes
# Out:
# VendorNumber               int64
# VendorName                object
# Brand                     object
# Description               object
# PurchasePrice            float64
# ActualPrice              float64
# Volume                     int64
# TotalPurchaseQuantity      int64
# TotalPurchaseRupees      float64
# TotalSalesQuantity         int64
# TotalSalesRupees         float64
# TotalSalesPrice          float64
# TotalExciseTax           float64
# FreightCost              float64
# dtype: object

# %%
vendor_sales_summary.isnull().sum()
# Out:
# VendorNumber             0
# VendorName               0
# Brand                    0
# Description              0
# PurchasePrice            0
# ActualPrice              0
# Volume                   0
# TotalPurchaseQuantity    0
# TotalPurchaseRupees      0
# TotalSalesQuantity       0
# TotalSalesRupees         0
# TotalSalesPrice          0
# TotalExciseTax           0
# FreightCost              0
# dtype: int64

# %%
vendor_sales_summary['VendorName'].unique()
# Out:
# array(['Nestle Suppliers', 'Amul Wholesale', 'Tata Foods',
#        'Haldirams Distributors', 'Britannia Vendors'], dtype=object)

# %%
vendor_sales_summary['Description'].unique()
# Out:
# array(['Biscuits 1kg', 'Milk 100g', 'Butter 250ml', 'Milk 1kg',
#        'Tea 100g', 'Tea 200g', 'Chips 1kg', 'Salt 100g', 'Biscuits 500g',
#        'Coffee 100g', 'Butter 100g', 'Tea 1L', 'Salt 500g', 'Chips 250ml',
#        'Noodles 500g', 'Coffee 250ml', 'Milk 1L', 'Noodles 1kg',
#        'Biscuits 1L', 'Biscuits 100g', 'Milk 200g', 'Butter 500g',
#        'Noodles 100g', 'Chips 100g', 'Coffee 1kg', 'Tea 500g',
#        'Chips 200g', 'Salt 200g', 'Chips 1L', 'Salt 1L', 'Butter 1kg',
#        'Coffee 500g', 'Butter 1L', 'Noodles 250ml', 'Milk 250ml',
#        'Salt 250ml', 'Salt 1kg', 'Tea 250ml', 'Coffee 200g',
#        'Butter 200g', 'Noodles 1L', 'Coffee 1L', 'Milk 500g'],
#       dtype=object)

# %%
vendor_sales_summary['GrossProfit'] = vendor_sales_summary['TotalSalesRupees'] - vendor_sales_summary['TotalPurchaseRupees']

# %%
vendor_sales_summary
# Out:
#       VendorNumber        VendorName   Brand   Description  PurchasePrice  \
# 0             1001  Nestle Suppliers  Nestle  Biscuits 1kg         219.74
# 1             1001  Nestle Suppliers  Nestle  Biscuits 1kg         219.74
# 2             1001  Nestle Suppliers  Nestle  Biscuits 1kg         219.74
# 3             1001  Nestle Suppliers  Nestle  Biscuits 1kg         219.74
# 4             1001  Nestle Suppliers  Nestle  Biscuits 1kg         219.74
# ...            ...               ...     ...           ...            ...
# 2061          1001  Nestle Suppliers  Nestle  Noodles 100g          24.16
# 2062          1001  Nestle Suppliers  Nestle  Noodles 100g          24.16
# 2063          1001  Nestle Suppliers  Nestle  Noodles 100g          24.16
# 2064          1001  Nestle Suppliers  Nestle  Noodles 100g          24.16
# 2065          1001  Nestle Suppliers  Nestle  Noodles 100g          24.16
#
#       ActualPrice  Volume  TotalPurchaseQuantity  TotalPurchaseRupees  \
# ...

# %%
vendor_sales_summary['GrossProfit'].min()
# Out:
# 133322.9

# %%
vendor_sales_summary['ProfitMargin'] = (vendor_sales_summary['GrossProfit'] / vendor_sales_summary['TotalSalesRupees'])*100

# %%
vendor_sales_summary['StockTurnover'] = vendor_sales_summary['TotalSalesQuantity']/vendor_sales_summary['TotalPurchaseQuantity']

# %%
vendor_sales_summary['SalestoPurchaseRatio'] = vendor_sales_summary['TotalSalesRupees']/vendor_sales_summary['TotalPurchaseRupees']

# %%
vendor_sales_summary
# Out:
#       VendorNumber        VendorName   Brand   Description  PurchasePrice  \
# 0             1001  Nestle Suppliers  Nestle  Biscuits 1kg         219.74
# 1             1001  Nestle Suppliers  Nestle  Biscuits 1kg         219.74
# 2             1001  Nestle Suppliers  Nestle  Biscuits 1kg         219.74
# 3             1001  Nestle Suppliers  Nestle  Biscuits 1kg         219.74
# 4             1001  Nestle Suppliers  Nestle  Biscuits 1kg         219.74
# ...            ...               ...     ...           ...            ...
# 2061          1001  Nestle Suppliers  Nestle  Noodles 100g          24.16
# 2062          1001  Nestle Suppliers  Nestle  Noodles 100g          24.16
# 2063          1001  Nestle Suppliers  Nestle  Noodles 100g          24.16
# 2064          1001  Nestle Suppliers  Nestle  Noodles 100g          24.16
# 2065          1001  Nestle Suppliers  Nestle  Noodles 100g          24.16
#
#       ActualPrice  Volume  TotalPurchaseQuantity  TotalPurchaseRupees  \
# ...

# %%
vendor_sales_summary.dtypes
# Out:
# VendorNumber               int64
# VendorName                object
# Brand                     object
# Description               object
# PurchasePrice            float64
# ActualPrice              float64
# Volume                     int64
# TotalPurchaseQuantity      int64
# TotalPurchaseRupees      float64
# TotalSalesQuantity         int64
# TotalSalesRupees         float64
# TotalSalesPrice          float64
# TotalExciseTax           float64
# FreightCost              float64
# GrossProfit              float64
# ProfitMargin             float64
# StockTurnover            float64
# SalestoPurchaseRatio     float64
# dtype: object

# %%
cursor = conn.cursor()

# %%
cursor.execute("""CREATE TABLE vendor_sales_summary (
    VendorNumber INT,
    VendorName VARCHAR(100),
    Brand VARCHAR(100),
    Description VARCHAR(100),
    PurchasePrice DECIMAL(10,2),
    ActualPrice DECIMAL(10,2),
    Volume INT,
    TotalPurchaseQuantity INT,
    TotalPurchaseRupees DECIMAL(15,2),
    TotalSalesQuantity INT,
    TotalSalesRupees DECIMAL(15,2),
    TotalSalesPrice DECIMAL(15,2),
    TotalExciseTax DECIMAL(15,2),
    FreightCost DECIMAL(15,2),
    GrossProfit DECIMAL(15,2),
    ProfitMargin DECIMAL(15,2),
    StockTurnover DECIMAL(15,2),
    SalesToPurchaseRatio DECIMAL(15,2),
    PRIMARY KEY (VendorNumber, Brand)
);
""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 cursor.execute("""CREATE TABLE vendor_sales_summary (
#       2     VendorNumber INT,
#       3     VendorName VARCHAR(100),
#       4     Brand VARCHAR(100),
#       5     Description VARCHAR(100),
#       6     PurchasePrice DECIMAL(10,2),
#       7     ActualPrice DECIMAL(10,2),
#       8     Volume INT,
#       9     TotalPurchaseQuantity INT,
#      10     TotalPurchaseRupees DECIMAL(15,2),
#      11     TotalSalesQuantity INT,
#      12     TotalSalesRupees DECIMAL(15,2),
#      13     TotalSalesPrice DECIMAL(15,2),
#      14     TotalExciseTax DECIMAL(15,2),
#      15     FreightCost DECIMAL(15,2),
#      16     GrossProfit DECIMAL(15,2),
#      17     ProfitMargin DECIMAL(15,2),
#      18     StockTurnover DECIMAL(15,2),
#      19     SalesToPurchaseRatio DECIMAL(15,2),
# ...

# %%
pd.read_sql_query("select * from vendor_sales_summary",conn)
# Out:
#       VendorNumber        VendorName   Brand   Description  PurchasePrice  \
# 0             1001  Nestle Suppliers  Nestle  Biscuits 1kg         219.74
# 1             1001  Nestle Suppliers  Nestle  Biscuits 1kg         219.74
# 2             1001  Nestle Suppliers  Nestle  Biscuits 1kg         219.74
# 3             1001  Nestle Suppliers  Nestle  Biscuits 1kg         219.74
# 4             1001  Nestle Suppliers  Nestle  Biscuits 1kg         219.74
# ...            ...               ...     ...           ...            ...
# 2061          1001  Nestle Suppliers  Nestle  Noodles 100g          24.16
# 2062          1001  Nestle Suppliers  Nestle  Noodles 100g          24.16
# 2063          1001  Nestle Suppliers  Nestle  Noodles 100g          24.16
# 2064          1001  Nestle Suppliers  Nestle  Noodles 100g          24.16
# 2065          1001  Nestle Suppliers  Nestle  Noodles 100g          24.16
#
#       ActualPrice  Volume  TotalPurchaseQuantity  TotalPurchaseRupees  \
# ...

# %%
vendor_sales_summary.to_sql('vendor_sales_summary', conn, if_exists = 'replace', index = False )
# Out:
# 2066

# %%
pd.read_sql_query("select * from vendor_sales_summary",conn)
# Out:
#       VendorNumber        VendorName   Brand   Description  PurchasePrice  \
# 0             1001  Nestle Suppliers  Nestle  Biscuits 1kg         219.74
# 1             1001  Nestle Suppliers  Nestle  Biscuits 1kg         219.74
# 2             1001  Nestle Suppliers  Nestle  Biscuits 1kg         219.74
# 3             1001  Nestle Suppliers  Nestle  Biscuits 1kg         219.74
# 4             1001  Nestle Suppliers  Nestle  Biscuits 1kg         219.74
# ...            ...               ...     ...           ...            ...
# 2061          1001  Nestle Suppliers  Nestle  Noodles 100g          24.16
# 2062          1001  Nestle Suppliers  Nestle  Noodles 100g          24.16
# 2063          1001  Nestle Suppliers  Nestle  Noodles 100g          24.16
# 2064          1001  Nestle Suppliers  Nestle  Noodles 100g          24.16
# 2065          1001  Nestle Suppliers  Nestle  Noodles 100g          24.16
#
#       ActualPrice  Volume  TotalPurchaseQuantity  TotalPurchaseRupees  \
# ...

# %%
import sqlite3
import pandas as pd
import logging
from ingestion_db import ingest_db

logging.basicConfig(
    filename="logs/get_vendor.log",
    level=logging.DEBUG,
    format="%(asctime)s - %(leevelname)s - %(message)s",
    filemode="a"
)

def create_vendor_summary(conn):
    '''this function will merge the different tables to get the overall vendor summary and adding new columns in the resultant data'''
    vendor_sales_summary = pd.read_sql_query("""WITH FreightSummary AS (
    SELECT
        VendorNumber,
        SUM(Freight) AS FreightCost
    FROM vendor_invoice
    GROUP BY VendorNumber
    ),
    
    PurchaseSummary AS (
        SELECT
            p.VendorNumber,
            p.VendorName,
            p.Brand,
            p.Description,
            p.PurchasePrice,
            pp.Price AS ActualPrice,
            pp.Volume,
            SUM(p.Quantity) AS TotalPurchaseQuantity,
            SUM(p.Rupees) AS TotalPurchaseRupees
        FROM purchases p
        JOIN purchase_prices pp
            ON p.Brand = pp.Brand
        WHERE p.PurchasePrice > 0
        GROUP BY p.VendorNumber, p.VendorName, p.Brand, p.Description, p.PurchasePrice, pp.Price, pp.Volume
    ),
    
    SalesSummary AS (
        SELECT
            VendorNumber,
            Brand,
            SUM(SalesQuantity) AS TotalSalesQuantity,
            SUM(SalesRupees) AS TotalSalesRupees,
            SUM(SalesPrice) AS TotalSalesPrice,
            SUM(ExciseTax) AS TotalExciseTax
        FROM sales
        GROUP BY VendorNumber, Brand
    )
    
    SELECT
        ps.VendorNumber,
        ps.VendorName,
        ps.Brand,
        ps.Description,
        ps.PurchasePrice,
        ps.ActualPrice,
        ps.Volume,
        ps.TotalPurchaseQuantity,
        ps.TotalPurchaseRupees,
        ss.TotalSalesQuantity,
        ss.TotalSalesRupees,
        ss.TotalSalesPrice,
        ss.TotalExciseTax,
        fs.FreightCost
    FROM PurchaseSummary ps
    LEFT JOIN SalesSummary ss
        ON ps.VendorNumber = ss.VendorNumber
        AND ps.Brand = ss.Brand
    LEFT JOIN FreightSummary fs
        ON ps.VendorNumber = fs.VendorNumber
    ORDER BY ps.TotalPurchaseRupees DESC""",conn)

    return vendor_sales_summary


def clean_data(df):
    '''this function will clean the data'''

    # creating new columns for better analysis
    vendor_sales_summary['GrossProfit'] = vendor_sales_summary['TotalSalesRupees'] -  vendor_sales_summary['TotalPurchaseRupees']
    vendor_sales_summary['ProfitMargin'] = (vendor_sales_summary['GrossProfit'] / vendor_sales_summary['TotalSalesRupees'])*100
    vendor_sales_summary['StockTurnover'] = vendor_sales_summary['TotalSalesQuantity']/vendor_sales_summary['TotalPurchaseQuantity']
    vendor_sales_summary['SalestoPurchaseRatio'] = vendor_sales_summary['TotalSalesRupees']/vendor_sales_summary['TotalPurchaseRupees']


    return df

if __name__=='__main__':
    # creating database connection
    conn = sqlite3.connect('inventory.db')

    logging.info('Creating Vendor Summary Table.......')
    summary_df = create_vendor_summary(conn)
    logging.info(summary_df.head())

    logging.info('Cleaning Data....')
    clean_df = clean_data(summary_df)
    logging.info(clean_df.head())

    logging.info('Ingesting data......')
    ingest_db(clean_df,'vendor_sales_summary',conn)
    logging.info('Completed')

# %%
import pandas as pd
import os
from sqlalchemy import create_engine
import logging
import time

logging.basicConfig(
    filename="logs/ingestion_db.log",
    level=logging.DEBUG,
    format="%(asctime)s - %(levelname)s - %(message)s",
    filemode="a"
)

engine = create_engine('sqlite:///inventory.db')

def ingest_db(df, table_name, engine):
    '''this function will ingest the dataframe into database table'''
    df.to_sql(table_name, con = engine, if_exists = 'replace', index = False)

def load_raw_data():
    '''this function will load the CSVs as dataframe and ingest into db'''
    start = time.time()
    for file in os.listdir('data'):
        if '.csv' in file:
            df = pd.read_csv('data/'+file)
            logging.info(f'Ingesting {file} in db')
            ingest_db(df, file[:-4], engine)
    end = time.time()
    total_time = (end - start)/60
    logging.info('--------Ingestion Complete----------')
    
    logging.info(f'Total Time Taken: {total_time} minutes')

if __name__=='__main__':
    load_raw_data()

# %%
import sqlite3
import pandas as pd
import logging
from ingestion_db import ingest_db

logging.basicConfig(
    filename="logs/get_vendor.log",
    level=logging.DEBUG,
    format="%(asctime)s - %(leevelname)s - %(message)s",
    filemode="a"
)

def create_vendor_summary(conn):
    '''this function will merge the different tables to get the overall vendor summary and adding new columns in the resultant data'''
    vendor_sales_summary = pd.read_sql_query("""WITH FreightSummary AS (
    SELECT
        VendorNumber,
        SUM(Freight) AS FreightCost
    FROM vendor_invoice
    GROUP BY VendorNumber
    ),
    
    PurchaseSummary AS (
        SELECT
            p.VendorNumber,
            p.VendorName,
            p.Brand,
            p.Description,
            p.PurchasePrice,
            pp.Price AS ActualPrice,
            pp.Volume,
            SUM(p.Quantity) AS TotalPurchaseQuantity,
            SUM(p.Rupees) AS TotalPurchaseRupees
        FROM purchases p
        JOIN purchase_prices pp
            ON p.Brand = pp.Brand
        WHERE p.PurchasePrice > 0
        GROUP BY p.VendorNumber, p.VendorName, p.Brand, p.Description, p.PurchasePrice, pp.Price, pp.Volume
    ),
    
    SalesSummary AS (
        SELECT
            VendorNumber,
            Brand,
            SUM(SalesQuantity) AS TotalSalesQuantity,
            SUM(SalesRupees) AS TotalSalesRupees,
            SUM(SalesPrice) AS TotalSalesPrice,
            SUM(ExciseTax) AS TotalExciseTax
        FROM sales
        GROUP BY VendorNumber, Brand
    )
    
    SELECT
        ps.VendorNumber,
        ps.VendorName,
        ps.Brand,
        ps.Description,
        ps.PurchasePrice,
        ps.ActualPrice,
        ps.Volume,
        ps.TotalPurchaseQuantity,
        ps.TotalPurchaseRupees,
        ss.TotalSalesQuantity,
        ss.TotalSalesRupees,
        ss.TotalSalesPrice,
        ss.TotalExciseTax,
        fs.FreightCost
    FROM PurchaseSummary ps
    LEFT JOIN SalesSummary ss
        ON ps.VendorNumber = ss.VendorNumber
        AND ps.Brand = ss.Brand
    LEFT JOIN FreightSummary fs
        ON ps.VendorNumber = fs.VendorNumber
    ORDER BY ps.TotalPurchaseRupees DESC""",conn)

    return vendor_sales_summary


def clean_data(df):
    '''this function will clean the data'''

    # creating new columns for better analysis
    vendor_sales_summary['GrossProfit'] = vendor_sales_summary['TotalSalesRupees'] -  vendor_sales_summary['TotalPurchaseRupees']
    vendor_sales_summary['ProfitMargin'] = (vendor_sales_summary['GrossProfit'] / vendor_sales_summary['TotalSalesRupees'])*100
    vendor_sales_summary['StockTurnover'] = vendor_sales_summary['TotalSalesQuantity']/vendor_sales_summary['TotalPurchaseQuantity']
    vendor_sales_summary['SalestoPurchaseRatio'] = vendor_sales_summary['TotalSalesRupees']/vendor_sales_summary['TotalPurchaseRupees']


    return df

if __name__=='__main__':
    # creating database connection
    conn = sqlite3.connect('inventory.db')

    logging.info('Creating Vendor Summary Table.......')
    summary_df = create_vendor_summary(conn)
    logging.info(summary_df.head())

    logging.info('Cleaning Data....')
    clean_df = clean_data(summary_df)
    logging.info(clean_df.head())

    logging.info('Ingesting data......')
    ingest_db(clean_df,'vendor_sales_summary',conn)
    logging.info('Completed')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:2674, in SQLiteDatabase.execute(self, sql, params)
#    2673 try:
# -> 2674     cur.execute(sql, *args)
#    2675     return cur
#
# OperationalError: near ",": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[129], line 96
#      93 conn = sqlite3.connect('inventory.db')
#      95 logging.info('Creating Vendor Summary Table.......')
# ---> 96 summary_df = create_vendor_summary(conn)
#      97 logging.info(summary_df.head())
#      99 logging.info('Cleaning Data....')
#
# Cell In[129], line 15, in create_vendor_summary(conn)
#      13 def create_vendor_summary(conn):
# ...

# %%
import sqlite3
import pandas as pd
import logging
from ingestion_db import ingest_db  

# Logging setup
logging.basicConfig(
    filename="logs/get_vendor.log",
    level=logging.DEBUG,
    format="%(asctime)s - %(levelname)s - %(message)s",
    filemode="a"
)

def create_vendor_summary(conn):
    '''Merge different tables to create vendor summary'''
    vendor_sales_summary = pd.read_sql_query("""WITH FreightSummary AS (
        SELECT
            VendorNumber,
            SUM(Freight) AS FreightCost
        FROM vendor_invoice
        GROUP BY VendorNumber
        ),
        
        PurchaseSummary AS (
            SELECT
                p.VendorNumber,
                p.VendorName,
                p.Brand,
                p.Description,
                p.PurchasePrice,
                pp.Price AS ActualPrice,
                pp.Volume,
                SUM(p.Quantity) AS TotalPurchaseQuantity,
                SUM(p.Rupees) AS TotalPurchaseRupees
            FROM purchases p
            JOIN purchase_prices pp
                ON p.Brand = pp.Brand
            WHERE p.PurchasePrice > 0
            GROUP BY p.VendorNumber, p.VendorName, p.Brand, p.Description, p.PurchasePrice, pp.Price, pp.Volume
        ),
        
        SalesSummary AS (
            SELECT
                VendorNumber,
                Brand,
                SUM(SalesQuantity) AS TotalSalesQuantity,
                SUM(SalesRupees) AS TotalSalesRupees,
                SUM(SalesPrice) AS TotalSalesPrice,
                SUM(ExciseTax) AS TotalExciseTax
            FROM sales
            GROUP BY VendorNumber, Brand
        )
        
        SELECT
            ps.VendorNumber,
            ps.VendorName,
            ps.Brand,
            ps.Description,
            ps.PurchasePrice,
            ps.ActualPrice,
            ps.Volume,
            ps.TotalPurchaseQuantity,
            ps.TotalPurchaseRupees,
            ss.TotalSalesQuantity,
            ss.TotalSalesRupees,
            ss.TotalSalesPrice,
            ss.TotalExciseTax,
            fs.FreightCost
        FROM PurchaseSummary ps
        LEFT JOIN SalesSummary ss
            ON ps.VendorNumber = ss.VendorNumber
            AND ps.Brand = ss.Brand
        LEFT JOIN FreightSummary fs
            ON ps.VendorNumber = fs.VendorNumber
        ORDER BY ps.TotalPurchaseRupees DESC""", conn)

    return vendor_sales_summary

def clean_data(df):
    '''Clean and enrich vendor summary data'''
    df['GrossProfit'] = df['TotalSalesRupees'] - df['TotalPurchaseRupees']
    df['ProfitMargin'] = (df['GrossProfit'] / df['TotalSalesRupees']) * 100
    df['StockTurnover'] = df['TotalSalesQuantity'] / df['TotalPurchaseQuantity']
    df['SalestoPurchaseRatio'] = df['TotalSalesRupees'] / df['TotalPurchaseRupees']
    return df

if __name__ == '__main__':
    conn = sqlite3.connect('inventory.db')

    logging.info('Creating Vendor Summary Table.......')
    summary_df = create_vendor_summary(conn)
    logging.info(summary_df.head())

    logging.info('Cleaning Data....')
    clean_df = clean_data(summary_df)
    logging.info(clean_df.head())

    logging.info('Ingesting data......')
    ingest_db(clean_df, 'vendor_sales_summary', conn)
    logging.info('Completed')

# %%
import sqlite3
import pandas as pd
import logging
from ingestion_db import ingest_db

logging.basicConfig(
    filename="logs/get_vendor.log",
    level=logging.DEBUG,
    format="%(asctime)s - %(levelname)s - %(message)s",
    filemode="a"
)

def create_vendor_summary(conn):
    '''this function will merge the different tables to get the overall vendor summary and adding new columns in the resultant data'''
    vendor_sales_summary = pd.read_sql_query("""WITH FreightSummary AS (
    SELECT
        VendorNumber,
        SUM(Freight) AS FreightCost
    FROM vendor_invoice
    GROUP BY VendorNumber
    ),
    
    PurchaseSummary AS (
        SELECT
            p.VendorNumber,
            p.VendorName,
            p.Brand,
            p.Description,
            p.PurchasePrice,
            pp.Price AS ActualPrice,
            pp.Volume,
            SUM(p.Quantity) AS TotalPurchaseQuantity,
            SUM(p.Rupees) AS TotalPurchaseRupees
        FROM purchases p
        JOIN purchase_prices pp
            ON p.Brand = pp.Brand
        WHERE p.PurchasePrice > 0
        GROUP BY p.VendorNumber, p.VendorName, p.Brand, p.Description, p.PurchasePrice, pp.Price, pp.Volume
    ),
    
    SalesSummary AS (
        SELECT
            VendorNumber,
            Brand,
            SUM(SalesQuantity) AS TotalSalesQuantity,
            SUM(SalesRupees) AS TotalSalesRupees,
            SUM(SalesPrice) AS TotalSalesPrice,
            SUM(ExciseTax) AS TotalExciseTax
        FROM sales
        GROUP BY VendorNumber, Brand
    )
    
    SELECT
        ps.VendorNumber,
        ps.VendorName,
        ps.Brand,
        ps.Description,
        ps.PurchasePrice,
        ps.ActualPrice,
        ps.Volume,
        ps.TotalPurchaseQuantity,
        ps.TotalPurchaseRupees,
        ss.TotalSalesQuantity,
        ss.TotalSalesRupees,
        ss.TotalSalesPrice,
        ss.TotalExciseTax,
        fs.FreightCost
    FROM PurchaseSummary ps
    LEFT JOIN SalesSummary ss
        ON ps.VendorNumber = ss.VendorNumber
        AND ps.Brand = ss.Brand
    LEFT JOIN FreightSummary fs
        ON ps.VendorNumber = fs.VendorNumber
    ORDER BY ps.TotalPurchaseRupees DESC""",conn)

    return vendor_sales_summary


def clean_data(df):
    '''this function will clean the data'''

    # creating new columns for better analysis
    vendor_sales_summary['GrossProfit'] = vendor_sales_summary['TotalSalesRupees'] -  vendor_sales_summary['TotalPurchaseRupees']
    vendor_sales_summary['ProfitMargin'] = (vendor_sales_summary['GrossProfit'] / vendor_sales_summary['TotalSalesRupees'])*100
    vendor_sales_summary['StockTurnover'] = vendor_sales_summary['TotalSalesQuantity']/vendor_sales_summary['TotalPurchaseQuantity']
    vendor_sales_summary['SalestoPurchaseRatio'] = vendor_sales_summary['TotalSalesRupees']/vendor_sales_summary['TotalPurchaseRupees']


    return df

if __name__=='__main__':
    # creating database connection
    conn = sqlite3.connect('inventory.db')

    logging.info('Creating Vendor Summary Table.......')
    summary_df = create_vendor_summary(conn)
    logging.info(summary_df.head())

    logging.info('Cleaning Data....')
    clean_df = clean_data(summary_df)
    logging.info(clean_df.head())

    logging.info('Ingesting data......')
    ingest_db(clean_df,'vendor_sales_summary',conn)
    logging.info('Completed')

# %%
import sqlite3
import pandas as pd
import logging
from ingestion_db import ingest_db

logging.basicConfig(
    filename="logs/get_vendor.log",
    level=logging.DEBUG,
    format="%(asctime)s - %(levelname)s - %(message)s",
    filemode="a"
)

def create_vendor_summary(conn):
    '''this function will merge the different tables to get the overall vendor summary and adding new columns in the resultant data'''
    vendor_sales_summary = pd.read_sql_query("""WITH FreightSummary AS (
    SELECT
        VendorNumber,
        SUM(Freight) AS FreightCost
    FROM vendor_invoice
    GROUP BY VendorNumber
    ),
    
    PurchaseSummary AS (
        SELECT
            p.VendorNumber,
            p.VendorName,
            p.Brand,
            p.Description,
            p.PurchasePrice,
            pp.Price AS ActualPrice,
            pp.Volume,
            SUM(p.Quantity) AS TotalPurchaseQuantity,
            SUM(p.Rupees) AS TotalPurchaseRupees
        FROM purchases p
        JOIN purchase_prices pp
            ON p.Brand = pp.Brand
        WHERE p.PurchasePrice > 0
        GROUP BY p.VendorNumber, p.VendorName, p.Brand, p.Description, p.PurchasePrice, pp.Price, pp.Volume
    ),
    
    SalesSummary AS (
        SELECT
            VendorNumber,
            Brand,
            SUM(SalesQuantity) AS TotalSalesQuantity,
            SUM(SalesRupees) AS TotalSalesRupees,
            SUM(SalesPrice) AS TotalSalesPrice,
            SUM(ExciseTax) AS TotalExciseTax
        FROM sales
        GROUP BY VendorNumber, Brand
    )
    
    SELECT
        ps.VendorNumber,
        ps.VendorName,
        ps.Brand,
        ps.Description,
        ps.PurchasePrice,
        ps.ActualPrice,
        ps.Volume,
        ps.TotalPurchaseQuantity,
        ps.TotalPurchaseRupees,
        ss.TotalSalesQuantity,
        ss.TotalSalesRupees,
        ss.TotalSalesPrice,
        ss.TotalExciseTax,
        fs.FreightCost
    FROM PurchaseSummary ps
    LEFT JOIN SalesSummary ss
        ON ps.VendorNumber = ss.VendorNumber
        AND ps.Brand = ss.Brand
    LEFT JOIN FreightSummary fs
        ON ps.VendorNumber = fs.VendorNumber
    ORDER BY ps.TotalPurchaseRupees DESC""",conn)

    return vendor_sales_summary


def clean_data(df):
    '''this function will clean the data'''

    # creating new columns for better analysis
    vendor_sales_summary['GrossProfit'] = vendor_sales_summary['TotalSalesRupees'] -  vendor_sales_summary['TotalPurchaseRupees']
    vendor_sales_summary['ProfitMargin'] = (vendor_sales_summary['GrossProfit'] / vendor_sales_summary['TotalSalesRupees'])*100
    vendor_sales_summary['StockTurnover'] = vendor_sales_summary['TotalSalesQuantity']/vendor_sales_summary['TotalPurchaseQuantity']
    vendor_sales_summary['SalestoPurchaseRatio'] = vendor_sales_summary['TotalSalesRupees']/vendor_sales_summary['TotalPurchaseRupees']


    return df

if __name__=='__main__':
    # creating database connection
    conn = sqlite3.connect('inventory.db')

    logging.info('Creating Vendor Summary Table.......')
    summary_df = create_vendor_summary(conn)
    logging.info(summary_df.head())

    logging.info('Cleaning Data....')
    clean_df = clean_data(summary_df)
    logging.info(clean_df.head())

    logging.info('Ingesting data......')
    ingest_db(clean_df,'vendor_sales_summary',conn)
    logging.info('Completed')

# %%
import sqlite3
import pandas as pd
import logging
from ingestion_db import ingest_db

logging.basicConfig(
    filename="logs/get_vendor.log",
    level=logging.DEBUG,
    format="%(asctime)s - %(levelname)s - %(message)s",
    filemode="a"
)

def create_vendor_summary(conn):
    '''this function will merge the different tables to get the overall vendor summary and adding new columns in the resultant data'''
    vendor_sales_summary = pd.read_sql_query("""WITH FreightSummary AS (
    SELECT
        VendorNumber,
        SUM(Freight) AS FreightCost
    FROM vendor_invoice
    GROUP BY VendorNumber
    ),
    
    PurchaseSummary AS (
        SELECT
            p.VendorNumber,
            p.VendorName,
            p.Brand,
            p.Description,
            p.PurchasePrice,
            pp.Price AS ActualPrice,
            pp.Volume,
            SUM(p.Quantity) AS TotalPurchaseQuantity,
            SUM(p.Rupees) AS TotalPurchaseRupees
        FROM purchases p
        JOIN purchase_prices pp
            ON p.Brand = pp.Brand
        WHERE p.PurchasePrice > 0
        GROUP BY p.VendorNumber, p.VendorName, p.Brand, p.Description, p.PurchasePrice, pp.Price, pp.Volume
    ),
    
    SalesSummary AS (
        SELECT
            VendorNumber,
            Brand,
            SUM(SalesQuantity) AS TotalSalesQuantity,
            SUM(SalesRupees) AS TotalSalesRupees,
            SUM(SalesPrice) AS TotalSalesPrice,
            SUM(ExciseTax) AS TotalExciseTax
        FROM sales
        GROUP BY VendorNumber, Brand
    )
    
    SELECT
        ps.VendorNumber,
        ps.VendorName,
        ps.Brand,
        ps.Description,
        ps.PurchasePrice,
        ps.ActualPrice,
        ps.Volume,
        ps.TotalPurchaseQuantity,
        ps.TotalPurchaseRupees,
        ss.TotalSalesQuantity,
        ss.TotalSalesRupees,
        ss.TotalSalesPrice,
        ss.TotalExciseTax,
        fs.FreightCost
    FROM PurchaseSummary ps
    LEFT JOIN SalesSummary ss
        ON ps.VendorNumber = ss.VendorNumber
        AND ps.Brand = ss.Brand
    LEFT JOIN FreightSummary fs
        ON ps.VendorNumber = fs.VendorNumber
    ORDER BY ps.TotalPurchaseRupees DESC""",conn)

    return vendor_sales_summary


def clean_data(df):
    '''this function will clean the data'''

    # creating new columns for better analysis
    vendor_sales_summary['GrossProfit'] = vendor_sales_summary['TotalSalesRupees'] -  vendor_sales_summary['TotalPurchaseRupees']
    vendor_sales_summary['ProfitMargin'] = (vendor_sales_summary['GrossProfit'] / vendor_sales_summary['TotalSalesRupees'])*100
    vendor_sales_summary['StockTurnover'] = vendor_sales_summary['TotalSalesQuantity']/vendor_sales_summary['TotalPurchaseQuantity']
    vendor_sales_summary['SalestoPurchaseRatio'] = vendor_sales_summary['TotalSalesRupees']/vendor_sales_summary['TotalPurchaseRupees']


    return df

if __name__=='__main__':
    # creating database connection
    conn = sqlite3.connect('inventory.db')

    logging.info('Creating Vendor Summary Table.......')
    summary_df = create_vendor_summary(conn)
    logging.info(summary_df.head())

    logging.info('Cleaning Data....')
    clean_df = clean_data(summary_df)
    logging.info(clean_df.head())

    logging.info('Ingesting data......')
    ingest_db(clean_df,'vendor_sales_summary',conn)
    logging.info('Completed')

# %%
import sqlite3
import pandas as pd
import logging
from ingestion_db import ingest_db  

# Logging setup
logging.basicConfig(
    filename="logs/get_vendor.log",
    level=logging.DEBUG,
    format="%(asctime)s - %(levelname)s - %(message)s",
    filemode="a"
)

def create_vendor_summary(conn):
    '''Merge different tables to create vendor summary'''
    vendor_sales_summary = pd.read_sql_query("""WITH FreightSummary AS (
        SELECT
            VendorNumber,
            SUM(Freight) AS FreightCost
        FROM vendor_invoice
        GROUP BY VendorNumber
        ),
        
        PurchaseSummary AS (
            SELECT
                p.VendorNumber,
                p.VendorName,
                p.Brand,
                p.Description,
                p.PurchasePrice,
                pp.Price AS ActualPrice,
                pp.Volume,
                SUM(p.Quantity) AS TotalPurchaseQuantity,
                SUM(p.Rupees) AS TotalPurchaseRupees
            FROM purchases p
            JOIN purchase_prices pp
                ON p.Brand = pp.Brand
            WHERE p.PurchasePrice > 0
            GROUP BY p.VendorNumber, p.VendorName, p.Brand, p.Description, p.PurchasePrice, pp.Price, pp.Volume
        ),
        
        SalesSummary AS (
            SELECT
                VendorNumber,
                Brand,
                SUM(SalesQuantity) AS TotalSalesQuantity,
                SUM(SalesRupees) AS TotalSalesRupees,
                SUM(SalesPrice) AS TotalSalesPrice,
                SUM(ExciseTax) AS TotalExciseTax
            FROM sales
            GROUP BY VendorNumber, Brand
        )
        
        SELECT
            ps.VendorNumber,
            ps.VendorName,
            ps.Brand,
            ps.Description,
            ps.PurchasePrice,
            ps.ActualPrice,
            ps.Volume,
            ps.TotalPurchaseQuantity,
            ps.TotalPurchaseRupees,
            ss.TotalSalesQuantity,
            ss.TotalSalesRupees,
            ss.TotalSalesPrice,
            ss.TotalExciseTax,
            fs.FreightCost
        FROM PurchaseSummary ps
        LEFT JOIN SalesSummary ss
            ON ps.VendorNumber = ss.VendorNumber
            AND ps.Brand = ss.Brand
        LEFT JOIN FreightSummary fs
            ON ps.VendorNumber = fs.VendorNumber
        ORDER BY ps.TotalPurchaseRupees DESC""", conn)

    return vendor_sales_summary

def clean_data(df):
    '''Clean and enrich vendor summary data'''
    df['GrossProfit'] = df['TotalSalesRupees'] - df['TotalPurchaseRupees']
    df['ProfitMargin'] = (df['GrossProfit'] / df['TotalSalesRupees']) * 100
    df['StockTurnover'] = df['TotalSalesQuantity'] / df['TotalPurchaseQuantity']
    df['SalestoPurchaseRatio'] = df['TotalSalesRupees'] / df['TotalPurchaseRupees']
    return df

if __name__ == '__main__':
    conn = sqlite3.connect('inventory.db')

    logging.info('Creating Vendor Summary Table.......')
    summary_df = create_vendor_summary(conn)
    logging.info(summary_df.head())

    logging.info('Cleaning Data....')
    clean_df = clean_data(summary_df)
    logging.info(clean_df.head())

    logging.info('Ingesting data......')
    ingest_db(clean_df, 'vendor_sales_summary', conn)
    logging.info('Completed')

# %%
pd.read_sql_query("select * from vendor_sales_summary",conn)
# Out:
#       VendorNumber        VendorName   Brand   Description  PurchasePrice  \
# 0             1001  Nestle Suppliers  Nestle  Biscuits 1kg         219.74
# 1             1001  Nestle Suppliers  Nestle  Biscuits 1kg         219.74
# 2             1001  Nestle Suppliers  Nestle  Biscuits 1kg         219.74
# 3             1001  Nestle Suppliers  Nestle  Biscuits 1kg         219.74
# 4             1001  Nestle Suppliers  Nestle  Biscuits 1kg         219.74
# ...            ...               ...     ...           ...            ...
# 2061          1001  Nestle Suppliers  Nestle  Noodles 100g          24.16
# 2062          1001  Nestle Suppliers  Nestle  Noodles 100g          24.16
# 2063          1001  Nestle Suppliers  Nestle  Noodles 100g          24.16
# 2064          1001  Nestle Suppliers  Nestle  Noodles 100g          24.16
# 2065          1001  Nestle Suppliers  Nestle  Noodles 100g          24.16
#
#       ActualPrice  Volume  TotalPurchaseQuantity  TotalPurchaseRupees  \
# ...

# %%
import pandas as pd

# Read the SQL table into a DataFrame
df = pd.read_sql_query("SELECT * FROM vendor_sales_summary", conn)

# Save the DataFrame to a CSV file
df.to_csv("vendor_sales_summary.csv", index=False)
